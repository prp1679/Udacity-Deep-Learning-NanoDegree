# %% [markdown]
# # Monte Carlo Methods
#
# In this notebook, you will write your own implementations of many Monte Carlo (MC) algorithms.
#
# While we have provided some starter code, you are welcome to erase these hints and write your code from scratch.
#
# ### Part 0: Explore BlackjackEnv
#
# We begin by importing the necessary packages.

# %%
import sys
import gym
import numpy as np
from collections import defaultdict

from plot_utils import plot_blackjack_values, plot_policy

# %% [markdown]
# Use the code cell below to create an instance of the [Blackjack](https://github.com/openai/gym/blob/master/gym/envs/toy_text/blackjack.py) environment.

# %%
env = gym.make('Blackjack-v0')

# %% [markdown]
# Each state is a 3-tuple of:
# - the player's current sum $\in \{0, 1, \ldots, 31\}$,
# - the dealer's face up card $\in \{1, \ldots, 10\}$, and
# - whether or not the player has a usable ace (`no` $=0$, `yes` $=1$).
#
# The agent has two potential actions:
#
# ```
#     STICK = 0
#     HIT = 1
# ```
# Verify this by running the code cell below.

# %%
print(env.observation_space)
print(env.action_space)
# Out:
# Tuple(Discrete(32), Discrete(11), Discrete(2))
# Discrete(2)

# %% [markdown]
# Execute the code cell below to play Blackjack with a random policy.
#
# (_The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to get some experience with the output that is returned as the agent interacts with the environment._)

# %%
for i_episode in range(3):
    state = env.reset()
    while True:
        print("current state: ", state)
        action = env.action_space.sample()
        print("Hit(1, keep playing) and Stick(0, stop playing)")
        print("The player's next action is ",action)
        state, reward, done, info = env.step(action)
        print("New State: {0} Reward: {1} and Done: {2} ".format(state,reward, done))
        if done:
            print('End game! Reward: ', reward)
            print('You won :)\n') if reward > 0 else print('You lost :(\n')
            break
# Out:
# current state:  (12, 10, False)
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (12, 10, False) Reward: -1.0 and Done: True
# End game! Reward:  -1.0
# You lost :(
#
# current state:  (19, 2, True)
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 2, False) Reward: 0 and Done: False
# current state:  (15, 2, False)
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 2, False) Reward: -1 and Done: True
# End game! Reward:  -1
# You lost :(
#
# current state:  (20, 10, False)
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, False) Reward: 0.0 and Done: True
# End game! Reward:  0.0
# You lost :(

# %% [markdown]
# ### Part 1: MC Prediction
#
# In this section, you will write your own implementation of MC prediction (for estimating the action-value function).
#
# We will begin by investigating a policy where the player _almost_ always sticks if the sum of her cards exceeds 18.  In particular, she selects action `STICK` with 80% probability if the sum is greater than 18; and, if the sum is 18 or below, she selects action `HIT` with 80% probability.  The function `generate_episode_from_limit_stochastic` samples an episode using this policy.
#
# The function accepts as **input**:
# - `bj_env`: This is an instance of OpenAI Gym's Blackjack environment.
#
# It returns as **output**:
# - `episode`: This is a list of (state, action, reward) tuples (of tuples) and corresponds to $(S_0, A_0, R_1, \ldots, S_{T-1}, A_{T-1}, R_{T})$, where $T$ is the final time step.  In particular, `episode[i]` returns $(S_i, A_i, R_{i+1})$, and `episode[i][0]`, `episode[i][1]`, and `episode[i][2]` return $S_i$, $A_i$, and $R_{i+1}$, respectively.

# %%
def generate_episode_from_limit_stochastic(bj_env):
    episode = []
    state = bj_env.reset()
    while True:
        print("current state: ", state)
        probs = [0.8, 0.2] if state[0] > 18 else [0.2, 0.8]
        action_space = np.arange(2)
        print("The action space is {0}".format(action_space))
        #action = np.random.choice(np.arange(2), p=probs)
        action = np.random.choice(action_space, p=probs)
        print("Hit(1, keep playing) and Stick(0, stop playing)")
        print("The player's next action is ",action)
        next_state, reward, done, info = bj_env.step(action)
        print("New State: {0} Reward: {1} and Done: {2} ".format(next_state,reward, done))
        episode.append((state, action, reward))
        #episode.append((next_state, action, reward))
        state = next_state
        print("\n")
        if done:
            break
    return episode

# %% [markdown]
# Execute the code cell below to play Blackjack with the policy.
#
# (*The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to gain some familiarity with the output of the `generate_episode_from_limit_stochastic` function.*)

# %%
for i in range(3):
    print("Starting episode {0}".format(i))
    episode_results =  generate_episode_from_limit_stochastic(env)
    print("Epsidoe {0} results".format(i))
    print("(state, action, reward)")
    print( episode_results)
    print("-" * 80)
# Out:
# Starting episode 0
# current state:  (15, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 10, False) Reward: -1 and Done: True
#
#
# Epsidoe 0 results
# (state, action, reward)
# [((15, 10, False), 1, -1)]
# --------------------------------------------------------------------------------
# Starting episode 1
# current state:  (13, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 6, False) Reward: 0 and Done: False
#
#
# current state:  (15, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 6, False) Reward: 0 and Done: False
#
#
# current state:  (17, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 6, False) Reward: -1 and Done: True
#
#
# Epsidoe 1 results
# (state, action, reward)
# [((13, 6, False), 1, 0), ((15, 6, False), 1, 0), ((17, 6, False), 1, -1)]
# --------------------------------------------------------------------------------
# Starting episode 2
# current state:  (11, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (13, 10, False) Reward: 0 and Done: False
#
#
# current state:  (13, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (16, 10, False) Reward: 0 and Done: False
#
#
# current state:  (16, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 10, False) Reward: -1 and Done: True
#
#
# Epsidoe 2 results
# (state, action, reward)
# [((11, 10, False), 1, 0), ((13, 10, False), 1, 0), ((16, 10, False), 1, -1)]
# --------------------------------------------------------------------------------

# %% [markdown]
# Now, you are ready to write your own implementation of MC prediction.  Feel free to implement either first-visit or every-visit MC prediction; in the case of the Blackjack environment, the techniques are equivalent.
#
# Your algorithm has three arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `generate_episode`: This is a function that returns an episode of interaction.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.

# %%
print("env.action_space : ",env.action_space)
print("env.action_space.n: ",env.action_space.n)

returns_sum = defaultdict(lambda: np.zeros(env.action_space.n))
print("returns_sum: ",returns_sum)
# Out:
# env.action_space :  Discrete(2)
# env.action_space.n:  2
# returns_sum:  defaultdict(<function <lambda> at 0x7fd719d1cbf8>, {})

# %%
def mc_prediction_q(env, num_episodes, generate_episode, gamma=1.0):
    # initialize empty dictionaries of arrays
    returns_sum = defaultdict(lambda: np.zeros(env.action_space.n))
    N = defaultdict(lambda: np.zeros(env.action_space.n))
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        
        #generate an episode
        episode = generate_episode(env)
        
        #Obtain the state, reward and done values 
        states, actions, rewards, = zip(*episode)
        print("States :{0} Actions: {1} Rewards: {2}".format(states,actions, rewards))
        
        # prepare for discounting
        discounts = np.array([gamma**i for i in range(len(rewards)+1)])
        print("discounts : \n{0}".format(discounts))
    
        
        # update the sum of the returns, number of visits, and action-value 
        # function estimates for each state-action pair in the episode
        for i, state in enumerate(states):
            print("rewards[i:]: {0}".format(rewards[i:]))
            print("discounts[:-(1+i)] : {0}".format(discounts[:-(1+i)]))
            print("rewards[i:]*discounts[:-(1+i)] : {0}".format(rewards[i:]*discounts[:-(1+i)]))
            print("sum(rewards[i:]*discounts[:-(1+i)]) :{0}".format(sum(rewards[i:]*discounts[:-(1+i)])))
            
            returns_sum[state][actions[i]] += sum(rewards[i:]*discounts[:-(1+i)])
            N[state][actions[i]] += 1.0
            Q[state][actions[i]] = returns_sum[state][actions[i]] / N[state][actions[i]]
            print(" N[state][actions[i]] : {0}".format( N[state][actions[i]]))
            print("Q[state][actions[i]] : {0}".format(Q[state][actions[i]]))
            print("%%%%%%% \n")
        
    return Q

# %% [markdown]
# Use the cell below to obtain the action-value function estimate $Q$.  We have also plotted the corresponding state-value function.
#
# To check the accuracy of your implementation, compare the plot below to the corresponding plot in the solutions notebook **Monte_Carlo_Solution.ipynb**.

# %%
# obtain the action-value function
#Q = mc_prediction_q(env, 500000, generate_episode_from_limit_stochastic)
Q = mc_prediction_q(env, 500, generate_episode_from_limit_stochastic)

print("The Q values are: \n")
for k,v in Q.items():
    print("k :{0} \n v:{1}".format(k,v))

# obtain the corresponding state-value function
V_to_plot = dict((k,(k[0]>18)*(np.dot([0.8, 0.2],v)) + (k[0]<=18)*(np.dot([0.2, 0.8],v))) \
         for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V_to_plot)
# Out:
# current state:  (8, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 10, False) Reward: 0 and Done: False
#
#
# current state:  (18, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (18, 10, False) Reward: -1.0 and Done: True
#
#
# States :((8, 10, False), (18, 10, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (10, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 3, False) Reward: 0 and Done: False
#
#
# current state:  (20, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 3, False) Reward: 0.0 and Done: True
#
#
# States :((10, 3, False), (20, 3, False)) Actions: (1, 0) Rewards: (0, 0.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 0.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (18, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (25, 6, False) Reward: -1 and Done: True
#
#
# States :((18, 6, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (19, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 1, False) Reward: 1.0 and Done: True
#
#
# States :((19, 1, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (8, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (10, 9, False) Reward: 0 and Done: False
#
#
# current state:  (10, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (12, 9, False) Reward: 0 and Done: False
#
#
# current state:  (12, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (22, 9, False) Reward: -1 and Done: True
#
#
# States :((8, 9, False), (10, 9, False), (12, 9, False)) Actions: (1, 1, 1) Rewards: (0, 0, -1)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, -1)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0.  0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (13, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (23, 10, False) Reward: -1 and Done: True
#
#
# States :((13, 10, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (20, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 6, False) Reward: 1.0 and Done: True
#
#
# States :((20, 6, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (11, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, False) Reward: 0 and Done: False
#
#
# current state:  (21, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 10, False) Reward: 0.0 and Done: True
#
#
# States :((11, 10, False), (21, 10, False)) Actions: (1, 0) Rewards: (0, 0.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 0.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (19, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 10, False) Reward: -1.0 and Done: True
#
#
# States :((19, 10, False),) Actions: (0,) Rewards: (-1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (20, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 9, False) Reward: 1.0 and Done: True
#
#
# States :((20, 9, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (5, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 8, False) Reward: 0 and Done: False
#
#
# current state:  (15, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (25, 8, False) Reward: -1 and Done: True
#
#
# States :((5, 8, False), (15, 8, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (15, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (15, 10, False) Reward: -1.0 and Done: True
#
#
# States :((15, 10, False),) Actions: (0,) Rewards: (-1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (9, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 10, False) Reward: 0 and Done: False
#
#
# current state:  (19, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 10, False) Reward: -1.0 and Done: True
#
#
# States :((9, 10, False), (19, 10, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (18, 2, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 2, False) Reward: 0 and Done: False
#
#
# current state:  (15, 2, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 2, False) Reward: 0 and Done: False
#
#
# current state:  (18, 2, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (23, 2, False) Reward: -1 and Done: True
#
#
# States :((18, 2, True), (15, 2, False), (18, 2, False)) Actions: (1, 1, 1) Rewards: (0, 0, -1)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, -1)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0.  0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (19, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 5, False) Reward: 1.0 and Done: True
#
#
# States :((19, 5, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (16, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 10, True) Reward: 0 and Done: False
#
#
# current state:  (17, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, True) Reward: 0 and Done: False
#
#
# current state:  (21, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, False) Reward: 0 and Done: False
#
#
# current state:  (21, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 10, False) Reward: 1.0 and Done: True
#
#
# States :((16, 10, True), (17, 10, True), (21, 10, True), (21, 10, False)) Actions: (1, 1, 1, 0) Rewards: (0, 0, 0, 1.0)
# discounts :
# [1. 1. 1. 1. 1.]
# rewards[i:]: (0, 0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.5
# %%%%%%%
#
# current state:  (20, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 5, False) Reward: 0.0 and Done: True
#
#
# States :((20, 5, False),) Actions: (0,) Rewards: (0.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (12, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 7, False) Reward: 0 and Done: False
#
#
# current state:  (15, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 7, False) Reward: 0 and Done: False
#
#
# current state:  (20, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 7, False) Reward: 1.0 and Done: True
#
#
# States :((12, 7, False), (15, 7, False), (20, 7, False)) Actions: (1, 1, 0) Rewards: (0, 0, 1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (13, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (23, 3, False) Reward: -1 and Done: True
#
#
# States :((13, 3, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (20, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (30, 10, False) Reward: -1 and Done: True
#
#
# States :((20, 10, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (11, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 1, False) Reward: 0 and Done: False
#
#
# current state:  (19, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 1, False) Reward: -1.0 and Done: True
#
#
# States :((11, 1, False), (19, 1, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (11, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 10, False) Reward: 0 and Done: False
#
#
# current state:  (17, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, False) Reward: 0 and Done: False
#
#
# current state:  (21, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 10, False) Reward: 1.0 and Done: True
#
#
# States :((11, 10, False), (17, 10, False), (21, 10, False)) Actions: (1, 1, 0) Rewards: (0, 0, 1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.5
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 0.6666666666666666
# %%%%%%%
#
# current state:  (17, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 10, True) Reward: 0 and Done: False
#
#
# current state:  (20, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, True) Reward: 1.0 and Done: True
#
#
# States :((17, 10, True), (20, 10, True)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (15, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (16, 10, False) Reward: 0 and Done: False
#
#
# current state:  (16, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (26, 10, False) Reward: -1 and Done: True
#
#
# States :((15, 10, False), (16, 10, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (12, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 10, False) Reward: 0 and Done: False
#
#
# current state:  (20, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, False) Reward: 1.0 and Done: True
#
#
# States :((12, 10, False), (20, 10, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (14, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 8, False) Reward: 0 and Done: False
#
#
# current state:  (19, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 8, False) Reward: 1.0 and Done: True
#
#
# States :((14, 8, False), (19, 8, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (14, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 1, False) Reward: -1 and Done: True
#
#
# States :((14, 1, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (21, 3, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 3, True) Reward: 1.0 and Done: True
#
#
# States :((21, 3, True),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (20, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, False) Reward: 1.0 and Done: True
#
#
# States :((20, 10, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (17, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (27, 6, False) Reward: -1 and Done: True
#
#
# States :((17, 6, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (9, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 7, False) Reward: 0 and Done: False
#
#
# current state:  (19, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (28, 7, False) Reward: -1 and Done: True
#
#
# States :((9, 7, False), (19, 7, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (17, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (25, 1, False) Reward: -1 and Done: True
#
#
# States :((17, 1, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (19, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 9, False) Reward: 0.0 and Done: True
#
#
# States :((19, 9, False),) Actions: (0,) Rewards: (0.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (16, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 4, False) Reward: 0 and Done: False
#
#
# current state:  (17, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (17, 4, False) Reward: 0.0 and Done: True
#
#
# States :((16, 4, False), (17, 4, False)) Actions: (1, 0) Rewards: (0, 0.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 0.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (20, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 3, False) Reward: 1.0 and Done: True
#
#
# States :((20, 3, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.5
# %%%%%%%
#
# current state:  (17, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 8, False) Reward: 0 and Done: False
#
#
# current state:  (19, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (29, 8, False) Reward: -1 and Done: True
#
#
# States :((17, 8, False), (19, 8, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (19, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 10, True) Reward: 0.0 and Done: True
#
#
# States :((19, 10, True),) Actions: (0,) Rewards: (0.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (10, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 4, False) Reward: 0 and Done: False
#
#
# current state:  (20, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (26, 4, False) Reward: -1 and Done: True
#
#
# States :((10, 4, False), (20, 4, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (16, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 6, False) Reward: 0 and Done: False
#
#
# current state:  (17, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (17, 6, False) Reward: 0.0 and Done: True
#
#
# States :((16, 6, False), (17, 6, False)) Actions: (1, 0) Rewards: (0, 0.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 0.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (0.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [0.]
# sum(rewards[i:]*discounts[:-(1+i)]) :0.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (11, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 4, False) Reward: 0 and Done: False
#
#
# current state:  (21, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 4, False) Reward: 1.0 and Done: True
#
#
# States :((11, 4, False), (21, 4, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (20, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 6, False) Reward: 1.0 and Done: True
#
#
# States :((20, 6, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (18, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 10, False) Reward: 0 and Done: False
#
#
# current state:  (20, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, False) Reward: 1.0 and Done: True
#
#
# States :((18, 10, False), (20, 10, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (14, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 6, False) Reward: 0 and Done: False
#
#
# current state:  (18, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (18, 6, False) Reward: 1.0 and Done: True
#
#
# States :((14, 6, False), (18, 6, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (20, 2, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 2, False) Reward: 1.0 and Done: True
#
#
# States :((20, 2, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (17, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 6, True) Reward: 0 and Done: False
#
#
# current state:  (18, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (14, 6, False) Reward: 0 and Done: False
#
#
# current state:  (14, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (14, 6, False) Reward: 1.0 and Done: True
#
#
# States :((17, 6, True), (18, 6, True), (14, 6, False)) Actions: (1, 1, 0) Rewards: (0, 0, 1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (20, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (29, 1, False) Reward: -1 and Done: True
#
#
# States :((20, 1, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (20, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 9, False) Reward: 1.0 and Done: True
#
#
# States :((20, 9, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (20, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 6, False) Reward: 1.0 and Done: True
#
#
# States :((20, 6, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (19, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 5, False) Reward: 1.0 and Done: True
#
#
# States :((19, 5, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (13, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 9, False) Reward: 0 and Done: False
#
#
# current state:  (20, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (22, 9, False) Reward: -1 and Done: True
#
#
# States :((13, 9, False), (20, 9, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (13, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (15, 6, True) Reward: 0 and Done: False
#
#
# current state:  (15, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 6, True) Reward: 0 and Done: False
#
#
# current state:  (19, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 6, True) Reward: 1.0 and Done: True
#
#
# States :((13, 6, True), (15, 6, True), (19, 6, True)) Actions: (1, 1, 0) Rewards: (0, 0, 1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (18, 1, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 1, False) Reward: 0 and Done: False
#
#
# current state:  (18, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (18, 1, False) Reward: 1.0 and Done: True
#
#
# States :((18, 1, True), (18, 1, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (14, 6, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (13, 6, False) Reward: 0 and Done: False
#
#
# current state:  (13, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (13, 6, False) Reward: -1.0 and Done: True
#
#
# States :((14, 6, True), (13, 6, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (16, 2, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (16, 2, False) Reward: -1.0 and Done: True
#
#
# States :((16, 2, False),) Actions: (0,) Rewards: (-1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (17, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (27, 4, False) Reward: -1 and Done: True
#
#
# States :((17, 4, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (10, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (13, 3, False) Reward: 0 and Done: False
#
#
# current state:  (13, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 3, False) Reward: 0 and Done: False
#
#
# current state:  (20, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 3, False) Reward: -1.0 and Done: True
#
#
# States :((10, 3, False), (13, 3, False), (20, 3, False)) Actions: (1, 1, 0) Rewards: (0, 0, -1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, -1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0.  0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : -0.5
# %%%%%%%
#
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (15, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 10, True) Reward: 0 and Done: False
#
#
# current state:  (20, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, True) Reward: 1.0 and Done: True
#
#
# States :((15, 10, True), (20, 10, True)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (14, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 5, False) Reward: -1 and Done: True
#
#
# States :((14, 5, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (21, 5, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 5, False) Reward: 0 and Done: False
#
#
# current state:  (18, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 5, False) Reward: 0 and Done: False
#
#
# current state:  (19, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 5, False) Reward: 1.0 and Done: True
#
#
# States :((21, 5, True), (18, 5, False), (19, 5, False)) Actions: (1, 1, 0) Rewards: (0, 0, 1.0)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, 1.0)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (18, 5, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (18, 5, True) Reward: 1.0 and Done: True
#
#
# States :((18, 5, True),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (15, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 7, False) Reward: 0 and Done: False
#
#
# current state:  (20, 7, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (25, 7, False) Reward: -1 and Done: True
#
#
# States :((15, 7, False), (20, 7, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (21, 9, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 9, False) Reward: 0 and Done: False
#
#
# current state:  (21, 9, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (21, 9, False) Reward: 1.0 and Done: True
#
#
# States :((21, 9, True), (21, 9, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# current state:  (8, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (8, 10, False) Reward: -1.0 and Done: True
#
#
# States :((8, 10, False),) Actions: (0,) Rewards: (-1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (21, 10, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, False) Reward: 0 and Done: False
#
#
# current state:  (21, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (27, 10, False) Reward: -1 and Done: True
#
#
# States :((21, 10, True), (21, 10, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (7, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (11, 5, False) Reward: 0 and Done: False
#
#
# current state:  (11, 5, False)
# The action space is [0 1]
# ...
# %%%%%%%
#
# current state:  (12, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (18, 5, False) Reward: 0 and Done: False
#
#
# current state:  (18, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 5, False) Reward: 0 and Done: False
#
#
# current state:  (21, 5, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (31, 5, False) Reward: -1 and Done: True
#
#
# States :((12, 5, False), (18, 5, False), (21, 5, False)) Actions: (1, 1, 1) Rewards: (0, 0, -1)
# discounts :
# [1. 1. 1. 1.]
# rewards[i:]: (0, 0, -1)
# discounts[:-(1+i)] : [1. 1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0.  0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : -0.3333333333333333
# %%%%%%%
#
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 5.0
# Q[state][actions[i]] : -0.6
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (14, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 1, False) Reward: 0 and Done: False
#
#
# current state:  (21, 1, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (25, 1, False) Reward: -1 and Done: True
#
#
# States :((14, 1, False), (21, 1, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 10.0
# Q[state][actions[i]] : -0.8
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (16, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (26, 10, False) Reward: -1 and Done: True
#
#
# States :((16, 10, False),) Actions: (1,) Rewards: (-1,)
# discounts :
# [1. 1.]
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 13.0
# Q[state][actions[i]] : -0.5384615384615384
# %%%%%%%
#
# current state:  (18, 8, True)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 8, False) Reward: 0 and Done: False
#
#
# current state:  (17, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (27, 8, False) Reward: -1 and Done: True
#
#
# States :((18, 8, True), (17, 8, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 1.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 8.0
# Q[state][actions[i]] : -0.75
# %%%%%%%
#
# current state:  (13, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 8, False) Reward: 0 and Done: False
#
#
# current state:  (19, 8, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 8, False) Reward: 1.0 and Done: True
#
#
# States :((13, 8, False), (19, 8, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 6.0
# Q[state][actions[i]] : 0.6666666666666666
# %%%%%%%
#
# current state:  (20, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 4, False) Reward: 1.0 and Done: True
#
#
# States :((20, 4, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 4.0
# Q[state][actions[i]] : 0.75
# %%%%%%%
#
# current state:  (14, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (19, 10, False) Reward: 0 and Done: False
#
#
# current state:  (19, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (19, 10, False) Reward: -1.0 and Done: True
#
#
# States :((14, 10, False), (19, 10, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 14.0
# Q[state][actions[i]] : -0.35714285714285715
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 15.0
# Q[state][actions[i]] : -0.3333333333333333
# %%%%%%%
#
# current state:  (16, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (21, 10, False) Reward: 0 and Done: False
#
#
# current state:  (21, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (24, 10, False) Reward: -1 and Done: True
#
#
# States :((16, 10, False), (21, 10, False)) Actions: (1, 1) Rewards: (0, -1)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 14.0
# Q[state][actions[i]] : -0.5714285714285714
# %%%%%%%
#
# rewards[i:]: (-1,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 2.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# current state:  (10, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (20, 10, False) Reward: 0 and Done: False
#
#
# current state:  (20, 10, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 10, False) Reward: 1.0 and Done: True
#
#
# States :((10, 10, False), (20, 10, False)) Actions: (1, 0) Rewards: (0, 1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, 1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [0. 1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 5.0
# Q[state][actions[i]] : 0.2
# %%%%%%%
#
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 21.0
# Q[state][actions[i]] : 0.8571428571428571
# %%%%%%%
#
# current state:  (17, 3, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (17, 3, False) Reward: 1.0 and Done: True
#
#
# States :((17, 3, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 0.3333333333333333
# %%%%%%%
#
# current state:  (13, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  1
# New State: (17, 4, False) Reward: 0 and Done: False
#
#
# current state:  (17, 4, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (17, 4, False) Reward: -1.0 and Done: True
#
#
# States :((13, 4, False), (17, 4, False)) Actions: (1, 0) Rewards: (0, -1.0)
# discounts :
# [1. 1. 1.]
# rewards[i:]: (0, -1.0)
# discounts[:-(1+i)] : [1. 1.]
# rewards[i:]*discounts[:-(1+i)] : [ 0. -1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 4.0
# Q[state][actions[i]] : -1.0
# %%%%%%%
#
# rewards[i:]: (-1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [-1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :-1.0
#  N[state][actions[i]] : 3.0
# Q[state][actions[i]] : 0.0
# %%%%%%%
#
# current state:  (20, 6, False)
# The action space is [0 1]
# Hit(1, keep playing) and Stick(0, stop playing)
# The player's next action is  0
# New State: (20, 6, False) Reward: 1.0 and Done: True
#
#
# States :((20, 6, False),) Actions: (0,) Rewards: (1.0,)
# discounts :
# [1. 1.]
# rewards[i:]: (1.0,)
# discounts[:-(1+i)] : [1.]
# rewards[i:]*discounts[:-(1+i)] : [1.]
# sum(rewards[i:]*discounts[:-(1+i)]) :1.0
#  N[state][actions[i]] : 10.0
# Q[state][actions[i]] : 1.0
# %%%%%%%
#
# The Q values are:
#
# k :(8, 10, False)
#  v:[-1.  -0.5]
# k :(18, 10, False)
#  v:[-1.         -0.45454545]
# k :(10, 3, False)
#  v:[ 0.         -0.66666667]
# k :(20, 3, False)
#  v:[ 0.58333333 -1.        ]
# k :(18, 6, False)
#  v:[ 1.  -0.5]
# k :(19, 1, False)
#  v:[-0.4 -1. ]
# k :(8, 9, False)
#  v:[ 0. -1.]
# k :(10, 9, False)
#  v:[ 0.  -0.5]
# k :(12, 9, False)
#  v:[0. 0.]
# k :(13, 10, False)
#  v:[-1. -1.]
# k :(20, 6, False)
#  v:[ 1. -1.]
# k :(11, 10, False)
#  v:[-1.  0.]
# k :(21, 10, False)
#  v:[ 0.92307692 -1.        ]
# k :(19, 10, False)
#  v:[-0.33333333 -0.33333333]
# k :(20, 9, False)
#  v:[ 0.6 -1. ]
# k :(5, 8, False)
#  v:[ 0. -1.]
# k :(15, 8, False)
#  v:[ 0.         -0.66666667]
# k :(15, 10, False)
#  v:[-0.5        -0.27272727]
# k :(9, 10, False)
#  v:[0.33333333 0.33333333]
# k :(18, 2, True)
#  v:[-1. -1.]
# k :(15, 2, False)
#  v:[1.  0.2]
# k :(18, 2, False)
#  v:[-1. -1.]
# k :(19, 5, False)
#  v:[1. 0.]
# k :(16, 10, True)
#  v:[-1.  1.]
# k :(17, 10, True)
#  v:[0.  0.5]
# k :(21, 10, True)
#  v:[ 1.         -0.33333333]
# k :(20, 5, False)
#  v:[ 0.66666667 -1.        ]
# k :(12, 7, False)
#  v:[0. 0.]
# k :(15, 7, False)
#  v:[ 1.         -0.66666667]
# k :(20, 7, False)
#  v:[ 0.77777778 -1.        ]
# k :(13, 3, False)
#  v:[ 0.  -0.5]
# k :(20, 10, False)
#  v:[ 0.85714286 -1.        ]
# k :(11, 1, False)
#  v:[ 0. -1.]
# k :(17, 10, False)
#  v:[-1.         -0.86666667]
# k :(20, 10, True)
#  v:[0.5 1. ]
# k :(16, 10, False)
#  v:[-0.33333333 -0.57142857]
# k :(12, 10, False)
#  v:[-1.         -0.44444444]
# k :(14, 8, False)
#  v:[0. 0.]
# k :(19, 8, False)
#  v:[ 0.66666667 -1.        ]
# k :(14, 1, False)
#  v:[-1.  -0.8]
# k :(21, 3, True)
#  v:[1. 1.]
# k :(17, 6, False)
#  v:[-0.5 -0.4]
# k :(9, 7, False)
#  v:[ 0. -1.]
# k :(19, 7, False)
#  v:[ 0.33333333 -0.5       ]
# k :(17, 1, False)
#  v:[ 0. -1.]
# k :(19, 9, False)
#  v:[ 0.33333333 -1.        ]
# k :(16, 4, False)
#  v:[ 0.         -0.57142857]
# k :(17, 4, False)
#  v:[ 0. -1.]
# k :(17, 8, False)
#  v:[-1.   -0.75]
# k :(19, 10, True)
#  v:[0. 0.]
# k :(10, 4, False)
#  v:[0. 0.]
# k :(20, 4, False)
#  v:[ 0.75 -1.  ]
# k :(16, 6, False)
#  v:[ 0.   -0.25]
# k :(11, 4, False)
#  v:[ 0.         -0.33333333]
# k :(21, 4, False)
#  v:[1. 0.]
# k :(14, 6, False)
#  v:[ 1.         -0.33333333]
# k :(20, 2, False)
#  v:[ 0.4 -1. ]
# k :(17, 6, True)
#  v:[0. 1.]
# k :(18, 6, True)
#  v:[1. 1.]
# k :(20, 1, False)
#  v:[-0.33333333 -1.        ]
# k :(13, 9, False)
#  v:[-1.  -0.6]
# k :(13, 6, True)
#  v:[0. 1.]
# k :(15, 6, True)
#  v:[1. 0.]
# k :(19, 6, True)
#  v:[1. 0.]
# k :(18, 1, True)
#  v:[0. 1.]
# k :(18, 1, False)
#  v:[1. 0.]
# k :(14, 6, True)
#  v:[ 0. -1.]
# k :(13, 6, False)
#  v:[-1. -1.]
# k :(16, 2, False)
#  v:[-1.  -0.6]
# k :(15, 10, True)
#  v:[0. 1.]
# k :(14, 5, False)
#  v:[-1. -1.]
# k :(21, 5, True)
#  v:[1. 1.]
# k :(18, 5, False)
#  v:[ 0.  -0.6]
# k :(18, 5, True)
#  v:[1. 0.]
# k :(21, 9, True)
#  v:[1. 1.]
# k :(21, 9, False)
#  v:[1. 0.]
# k :(7, 5, False)
#  v:[ 0. -1.]
# k :(11, 5, False)
#  v:[0. 0.]
# k :(21, 3, False)
#  v:[ 1. -1.]
# k :(12, 3, False)
#  v:[0.   0.25]
# k :(17, 3, False)
#  v:[ 0.33333333 -1.        ]
# k :(21, 2, True)
#  v:[0.66666667 0.        ]
# k :(19, 6, False)
#  v:[ 0.33333333 -1.        ]
# k :(9, 2, False)
#  v:[1. 0.]
# k :(16, 3, False)
#  v:[ 0. -1.]
# k :(19, 8, True)
#  v:[ 1. -1.]
# k :(20, 8, False)
#  v:[ 0.5 -1. ]
# k :(14, 10, False)
#  v:[-1.         -0.35714286]
# k :(9, 9, False)
#  v:[1. 0.]
# k :(12, 1, False)
#  v:[-1.  0.]
# k :(16, 1, False)
#  v:[ 0.         -0.66666667]
# k :(21, 1, False)
#  v:[ 0.75 -1.  ]
# k :(17, 2, False)
#  v:[ 1. -1.]
# k :(10, 6, False)
#  v:[0. 1.]
# k :(21, 6, True)
#  v:[1. 0.]
# k :(13, 1, False)
#  v:[-1.  0.]
# k :(21, 7, True)
#  v:[1. 0.]
# k :(19, 7, True)
#  v:[-1.  0.]
# k :(12, 2, False)
#  v:[0. 0.]
# k :(19, 2, False)
#  v:[0.83333333 0.        ]
# k :(19, 9, True)
#  v:[0. 0.]
# k :(15, 4, False)
#  v:[ 0.  -0.4]
# k :(18, 4, False)
#  v:[ 0. -1.]
# k :(6, 10, False)
#  v:[0. 0.]
# k :(19, 3, False)
#  v:[ 0.5 -1. ]
# k :(17, 9, False)
#  v:[ 0. -1.]
# k :(21, 8, True)
#  v:[ 0.5 -1. ]
# k :(5, 5, False)
#  v:[-1.  0.]
# k :(14, 4, True)
#  v:[0. 1.]
# k :(12, 4, False)
#  v:[ 1. -1.]
# k :(4, 6, False)
#  v:[0. 0.]
# k :(11, 8, False)
#  v:[0.         0.33333333]
# k :(13, 2, False)
#  v:[ 1.         -0.33333333]
# k :(16, 5, False)
#  v:[ 0. -1.]
# k :(21, 5, False)
#  v:[ 1. -1.]
# k :(7, 6, False)
#  v:[ 0. -1.]
# k :(10, 7, False)
#  v:[-1.  0.]
# k :(13, 8, False)
#  v:[0. 0.]
# k :(18, 10, True)
#  v:[ 0.         -0.33333333]
# k :(15, 3, False)
#  v:[-1.  0.]
# k :(7, 3, False)
#  v:[ 0. -1.]
# k :(11, 3, False)
#  v:[ 0. -1.]
# k :(14, 3, False)
#  v:[0. 0.]
# k :(10, 10, False)
#  v:[0.  0.2]
# k :(7, 8, False)
#  v:[ 0. -1.]
# k :(6, 6, False)
#  v:[-1.  0.]
# k :(12, 6, False)
#  v:[-1.  0.]
# k :(15, 1, False)
#  v:[-1.         -0.66666667]
# k :(19, 4, False)
#  v:[0.5 0. ]
# k :(20, 7, True)
#  v:[1. 0.]
# k :(9, 4, False)
#  v:[0.  0.5]
# k :(12, 5, False)
#  v:[ 0.         -0.33333333]
# k :(13, 10, True)
#  v:[ 1. -1.]
# k :(13, 7, False)
#  v:[ 0.  -0.6]
# k :(15, 6, False)
#  v:[ 0.  -0.6]
# k :(20, 3, True)
#  v:[-1.  0.]
# k :(4, 10, False)
#  v:[-1.  0.]
# k :(8, 3, False)
#  v:[ 1. -1.]
# k :(11, 2, False)
#  v:[0. 0.]
# k :(18, 9, False)
#  v:[ 0. -1.]
# k :(18, 7, False)
#  v:[ 0.   -0.75]
# k :(18, 8, True)
#  v:[ 0. -1.]
# k :(21, 8, False)
#  v:[1. 0.]
# k :(18, 3, False)
#  v:[-1.  -0.5]
# k :(17, 5, False)
#  v:[ 0. -1.]
# k :(13, 5, False)
#  v:[ 1.  -0.5]
# k :(14, 4, False)
#  v:[-1.  0.]
# k :(11, 7, False)
#  v:[ 0. -1.]
# k :(16, 7, False)
#  v:[-1. -1.]
# k :(16, 5, True)
#  v:[ 0. -1.]
# k :(8, 7, False)
#  v:[ 1.         -0.33333333]
# k :(13, 4, False)
#  v:[ 0. -1.]
# k :(21, 1, True)
#  v:[1. 0.]
# k :(10, 2, False)
#  v:[ 0. -1.]
# k :(14, 10, True)
#  v:[0. 1.]
# k :(21, 4, True)
#  v:[1. 0.]
# k :(16, 8, False)
#  v:[-1.  -0.5]
# k :(14, 1, True)
#  v:[ 0. -1.]
# k :(16, 9, False)
#  v:[ 0. -1.]
# k :(11, 6, False)
#  v:[ 0.         -0.33333333]
# k :(17, 7, False)
#  v:[ 0. -1.]
# k :(9, 6, False)
#  v:[0. 0.]
# k :(14, 7, False)
#  v:[ 0. -1.]
# k :(15, 9, True)
#  v:[0. 1.]
# k :(14, 9, False)
#  v:[ 1.  -0.5]
# k :(6, 9, False)
#  v:[0. 1.]
# k :(12, 5, True)
#  v:[0. 1.]
# k :(15, 5, True)
#  v:[0. 1.]
# k :(10, 5, False)
#  v:[0. 1.]
# k :(13, 5, True)
#  v:[0. 1.]
# k :(15, 5, False)
#  v:[1. 0.]
# k :(16, 3, True)
#  v:[ 0. -1.]
# k :(6, 7, False)
#  v:[ 0. -1.]
# k :(4, 1, False)
#  v:[ 0. -1.]
# k :(15, 4, True)
#  v:[0. 0.]
# k :(10, 8, False)
#  v:[ 0. -1.]
# k :(21, 2, False)
#  v:[1. 0.]
# k :(5, 6, False)
#  v:[ 0. -1.]
# k :(19, 2, True)
#  v:[-1. -1.]
# k :(4, 4, False)
#  v:[0. 1.]
# k :(19, 5, True)
#  v:[1. 0.]
# k :(17, 3, True)
#  v:[ 0. -1.]
# k :(21, 6, False)
#  v:[0. 0.]
# k :(8, 5, False)
#  v:[ 0. -1.]
# k :(7, 7, False)
#  v:[1. 0.]
# k :(13, 8, True)
#  v:[1. 0.]
# k :(14, 2, False)
#  v:[ 0. -1.]
# k :(20, 6, True)
#  v:[1. 0.]
# k :(7, 10, False)
#  v:[0. 1.]
# k :(19, 4, True)
#  v:[-1.  0.]

# %% [markdown]
# ### Part 2: MC Control
#
# In this section, you will write your own implementation of constant-$\alpha$ MC control.
#
# Your algorithm has four arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `alpha`: This is the step-size parameter for the update step.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.
# - `policy`: This is a dictionary where `policy[s]` returns the action that the agent chooses after observing state `s`.
#
# (_Feel free to define additional functions to help you to organize your code._)

# %%
def generate_episode_from_Q(env, Q, epsilon, nA):
    """ generates an episode from following the epsilon-greedy policy """
    episode = []
    state = env.reset()
    while True:
       # action = np.random.choice(np.arange(nA), p=get_probs(Q[state], epsilon, nA)) \
       #                             if state in Q else env.action_space.sample()
        
        
        if state in Q:
            action = np.random.choice(np.arange(nA), p=get_probs(Q[state], epsilon, nA))
        else: 
            action = env.action_space.sample()
            
        next_state, reward, done, info = env.step(action)
        episode.append((state, action, reward))
        state = next_state
        if done:
            break
    return episode

def get_probs(Q_s, epsilon, nA):
    """ obtains the action probabilities corresponding to epsilon-greedy policy """
    policy_s = np.ones(nA) * epsilon / nA
    best_a = np.argmax(Q_s)
    policy_s[best_a] = 1 - epsilon + (epsilon / nA)
    return policy_s

def update_Q(env, episode, Q, alpha, gamma):
    """ updates the action-value function estimate using the most recent episode """
    states, actions, rewards = zip(*episode)
    # prepare for discounting
    discounts = np.array([gamma**i for i in range(len(rewards)+1)])
    for i, state in enumerate(states):
        old_Q = Q[state][actions[i]] 
        Q[state][actions[i]] = old_Q + alpha*(sum(rewards[i:]*discounts[:-(1+i)]) - old_Q)
    return Q

# %%
def mc_control(env, num_episodes, alpha, gamma=1.0, eps_start=1.0, eps_decay=.99999, eps_min=0.05):
    nA = env.action_space.n
    # initialize empty dictionary of arrays
    Q = defaultdict(lambda: np.zeros(nA))
    epsilon = eps_start
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        # set the value of epsilon
        epsilon = max(epsilon*eps_decay, eps_min)
        # generate an episode by following epsilon-greedy policy
        episode = generate_episode_from_Q(env, Q, epsilon, nA)
        # update the action-value function estimate using the episode
        Q = update_Q(env, episode, Q, alpha, gamma)
    # determine the policy corresponding to the final action-value function estimate
    policy = dict((k,np.argmax(v)) for k, v in Q.items())
    return policy, Q

# %% [markdown]
# Use the cell below to obtain the estimated optimal policy and action-value function.  Note that you should fill in your own values for the `num_episodes` and `alpha` parameters.

# %%
# obtain the estimated optimal policy and action-value function
policy, Q = mc_control(env, 500000, 0.02)
# Out:
# Episode 500000/500000.

# %% [markdown]
# Next, we plot the corresponding state-value function.

# %%
# obtain the corresponding state-value function
V = dict((k,np.max(v)) for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V)

# %% [markdown]
# Finally, we visualize the policy that is estimated to be optimal.

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# The **true** optimal policy $\pi_*$ can be found in Figure 5.2 of the [textbook](http://go.udacity.com/rl-textbook) (and appears below).  Compare your final estimate to the optimal policy - how close are you able to get?  If you are not happy with the performance of your algorithm, take the time to tweak the decay rate of $\epsilon$, change the value of $\alpha$, and/or run the algorithm for more episodes to attain better results.
#
# ![True Optimal Policy](images/optimal.png)
